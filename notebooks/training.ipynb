# %%
import matplotlib.pyplot as plt

# %%
tr_loss = (1.876, 0.974, 0.874, 0.830, 0.803, 0.782, 0.768, 0.758, 0.742, 0.733, 0.720, 0.712, 0.700, 0.693, 0.683, 0.674, 0.664, 0.651, 0.648, 0.648, 0.645, 0.645, 0.645, 0.643, 0.642, 0.639, 0.639, 0.637, 0.636, 0.637, 0.637, 0.636)

val_loss = (0.695, 0.608, 0.593, 0.584, 0.602, 0.560, 0.586, 0.584, 0.578, 0.567, 0.602, 0.587, 0.607, 0.587, 0.581, 0.613, 0.619, 0.604, 0.600, 0.589, 0.593, 0.605, 0.598, 0.613, 0.63, 0.606, 0.596, 0.615, 0.637, 0.609, 0.617, 0.637)

plt.figure(figsize=(10,10))
fontsize=20
plt.subplot(311)
plt.title('Training loss', fontsize=fontsize+5)
plt.xlabel('Epoch', fontsize=fontsize)
plt.ylabel('Loss value', fontsize=fontsize)
plt.xticks(fontsize=fontsize-5)
plt.yticks(fontsize=fontsize-5)
plt.plot(tr_loss)

plt.subplot(312)
plt.title('Validation loss', fontsize=fontsize+5)
plt.xlabel('Epoch', fontsize=fontsize)
plt.ylabel('Loss value', fontsize=fontsize)
plt.xticks(fontsize=fontsize-5)
plt.yticks(fontsize=fontsize-5)
plt.plot(val_loss)

plt.subplot(313)
plt.title('Losses on one graph', fontsize=fontsize+5)
plt.xlabel('Epoch', fontsize=fontsize)
plt.ylabel('Loss value', fontsize=fontsize)
plt.xticks(fontsize=fontsize-5)
plt.yticks(fontsize=fontsize-5)
plt.plot(tr_loss)
plt.plot(val_loss)
plt.legend(['Training loss', 'Validation loss'], fontsize=fontsize)
plt.tight_layout()
plt.show()
