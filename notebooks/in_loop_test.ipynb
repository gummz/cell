# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cells_loops = pd.read_csv('/home/gummz/cell/data/interim/pred/pred_2/LI_2019-02-05_emb5_pos4/tracked_centroids_loops.csv', sep=';')

# round the intensity column to 4 decimal places
cells_loops.intensity = np.round(cells_loops.intensity.values, 4)

# %%
nonzero = np.nonzero(cells_loops.in_loop.values)

# mean intensity of cells that are inside loops
print(np.mean(cells_loops[cells_loops.in_loop > 0.5].intensity))

# mean intenisty of cells that are not inside loops
print(np.mean(cells_loops[cells_loops.in_loop == 0].intensity))
# Out:
# 0.06365599999999999
# 0.10145718992704167

# %%
for idx, cell in cells_loops.groupby('particle'):
    print(idx, round(np.sum(np.gradient(cell.intensity)), 5))
# Out:
# 0 0.004
# 1 -0.0905
# 2 -0.00525
# 3 0.007
# 5 0.00145
# 6 0.00475
# 7 0.02865
# 8 0.02345
# 15 0.21415
# 20 -0.0485
# 21 -0.0149
# 24 0.00525
# 25 0.0316
# 28 0.01615
# 32 0.03125
# 34 -0.00355
# 35 0.02985
# 36 -0.02435
# 37 0.136
# 45 -0.0009
# 46 0.0033
# 48 0.2919
# 54 0.02955
# 59 0.00595
# 61 0.0755
# 62 0.0046
# 64 -0.0188
# 67 -0.00195
# 71 0.0479
# 72 0.0806
# 73 0.0156
# 74 0.0392
# 76 0.0259
# 79 0.0774
# 80 0.00745
# 81 -0.00185
# 82 -0.06895
# 83 -0.17015
# 85 0.018
# 88 -0.009
# 90 -0.0033
# 91 -0.16645
# 92 0.01055
# 93 -0.0799
# 94 0.0265
# 96 -0.04035
# 97 -0.29845
# 98 -0.014
# 99 -0.1195
# 100 -0.03225
# 101 0.0125
# 102 -0.0119
# 103 0.0218
# 104 -0.05685
# 105 0.10155
# 106 -0.13095
# 107 -0.0115
# 108 0.0001
# 109 -0.0078
# 110 -0.09395
# 111 -0.0366
# 113 0.37325
# 114 -0.02475
# 115 -0.0405
# 116 -0.02455
# 117 0.09675
# 118 -0.05095
# 119 0.0788
# 120 -0.0672
# 121 -0.0193
# 122 0.051
# 123 0.1081
# 124 0.05225
# 125 -0.09995
# 127 0.10945
# 128 -0.0476
# ...

# %% [markdown]
# ### Create 'beta' and 'turning_point' columns
#
# The columns in the csv file are the following
#
# timepoint
#
# cell_id
#
# x (the x, y, z are coordinates of the cell center)
#
# y
#
# z
#
# mask
#
# intensity (mean pixel intensity of the detected mask)
#
# inside_loop (is the cell, at this timepoint, inside a loop?)
#
# dist_loop (what is the distance from the cell to the nearest coordinate of a loop boundary? either of the loop the cell is inside of, or if the cell isn't inside a loop, then distance to the nearest loop)
#
# beta (is this a beta cell? i.e. does it go from dim to bright? this field can take three values: 0 for always dim, 1 for goes from dim to bright, and 2 for it is always bright)
#
# turning_point (is this the timepoint for which the cell turned from dim to bright?)

# %%
# create 'beta' column
threshold = 0.09
grad_thresh = 0.55
risen_thresh = 0.5
cells_loops_cp = cells_loops.copy()[cells_loops.frame < 155]
particles = [item[1] for item in cells_loops_cp.groupby('particle')]
always_bright = [np.all(cell.intensity > threshold) for cell in particles]
always_id = [np.unique(cell.particle) for cell, idxbool in zip(particles, always_bright)
                                if idxbool]

dim_to_bright = np.full(len(particles), False)
for i, cell in enumerate(particles):
        frames = cell.frame.values
        intensity = cell.intensity.values

        # skip tracks that were present at the start
        if np.all(frames[:3] == range(3)) and np.all(intensity[:3] > threshold / 2):
                continue
        
        grad = np.gradient(intensity)
        ascending = np.sum(grad > 0) / len(grad) > grad_thresh
        risen = np.sum(intensity > threshold) / len(intensity) > risen_thresh
        reach = np.max(intensity) > threshold
        if any((ascending, risen and reach)):
                dim_to_bright[i] = True
        # to_split5 = intensity[range(0, len(cell), 5)]
        # if len(to_split5) == 1:
        #         diff = intensity[-1] - intensity[0]
        #         dim_to_bright[i] = diff > threshold
        # else:
        #         grad5 = np.gradient(to_split5)
        #         if np.any(grad5 > threshold):
        #                 dim_to_bright[i] = True
        #         elif len(cell) > 80:
        #                 to_split20 = intensity[range(0, len(cell), 50)]
        #                 grad20 = np.gradient(to_split20)
        #                 print(np.mean(grad20))
        #                 if np.any(grad20 > threshold):
        #                         dim_to_bright[i] = True
        #         else:
        #                 dim_to_bright[i] = False

dim_to_bright_id = [np.unique(cell.particle)[0] for cell, idxbool in zip(particles, dim_to_bright)
                                if idxbool]

# bright_to_dim = [np.all(np.sum(np.gradient(cell.intensity)) < 0) & \
#                             (cell.intensity.iloc[0] > cell.intensity.iloc[-1])
#                     for cell in particles]
# bright_to_dim_id = [np.unique(cell.particle) for cell, idxbool in zip(particles, bright_to_dim)
#                                 if idxbool]

always_bool = cells_loops_cp.particle.isin(always_id)
dim_to_bright_bool = cells_loops_cp.particle.isin(dim_to_bright_id) & (~always_bool)
# bright_to_dim_bool = (cells_loops_cp.particle.isin(bright_to_dim_id) &
#                          (~always_bool) & (~dim_to_bright_bool))

# conditions = (
#         dim_to_bright_bool,
#         always_bool,
# )

# cells_loops_cp['beta'] = np.select(conditions, (1, 2))
cells_loops_cp['beta'] = cells_loops_cp.particle.isin(dim_to_bright_id)

# create 'turning point' column
always_first = [(np.unique(cell.particle)[0], np.unique(cell.intensity > 0.2, return_index=True)[1][-1]) for cell, idxbool in zip(particles, always_bright)]
dim_to_bright_first = [(np.unique(cell.particle)[0], np.unique(np.sum(np.gradient(cell.intensity)) > 0, return_index=True)[1][-1])
                          for cell, idxbool in zip(particles, dim_to_bright)
                          if idxbool]

# print(np.select(conditions, (1, 2)).shape, cells_loops.shape)

print(np.unique(cells_loops_cp['beta'], return_counts=True))
# Out:
# (array([False,  True]), array([623, 592]))

# %%
plt.figure(figsize=(20, 10))
plt.title('Cell intensities\nas function of time \n (all cells)', fontsize=20)
plt.xlabel('Time index', fontsize=20)
plt.ylabel('Intensity (from 0 to 1)', fontsize=20)

for idx, cell_traj in cells_loops[cells_loops.frame < 155].groupby('particle'):
    x = cell_traj.frame.values
    y = cell_traj.intensity.values
    if np.random.rand() > 0.0:
        plt.plot(x, y)

# %%
plt.figure(figsize=(20, 10))
plt.title('Cell intensities\nas function of time \n (all cells)', fontsize=20)
plt.xlabel('Time index', fontsize=20)
plt.ylabel('Intensity (from 0 to 1)', fontsize=20)
labels = ('beta', 'nonbeta')
for idx, cell_traj in cells_loops_cp[cells_loops_cp.frame < 155].groupby('particle'):
    beta = cell_traj.beta.values[0]
    x = cell_traj.frame.values
    y = cell_traj.intensity.values
    if np.random.rand() > 0.0:
        if beta:
            handle_beta = plt.plot(x, y, color='red', label='beta')
        else:
            handle_non = plt.plot(x, y, color='black', label='nonbeta')

plt.legend(handles=[handle_beta[0], handle_non[0]], labels=labels, fontsize=30)
plt.show()
