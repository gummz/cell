# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
data = (('(0, 0.1)',0.06388642413487133,0.05),
('(0, 0.2)',0.06024325351577347,0.1),
('(0, 0.3)',0.06173659054699947,0.14),
('(0, 0.4)',0.06871666143708817,0.19),
('(0, 0.5)',0.07600035023202872,0.22),
('(0, 0.6)',0.08735234369121962,0.27),
('(0, 0.7)',0.1003659174072138,0.32),
('(0, 0.8)',0.12451580306517712,0.37),
 ('(0, 0.9)', 0.17748719824433065, 0.45),
  ('(0, 1.0)', 0.45651708129984525, 0.69))


plt.plot([item[0] for item in data], [item[1] for item in data])
plt.ylabel('Positive ratio')
plt.xlabel('Rejection threshold (4 means reject below 40% etc.)')
plt.xticks(range(10))
plt.title('Model calibration')
plt.ylim(bottom=0, top=1)
plt.show()
