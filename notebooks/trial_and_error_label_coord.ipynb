# %%
import matplotlib.pyplot as plt
import src.data.constants as c
import os.path as osp
import PIL.Image

# %%
data_dir = c.DATA_DIR if osp.exists(c.DATA_DIR) else c.PROJECT_DATA_DIR_FULL
label_dir_rel = 'pred/eval/track_2D/test'
file_name = 'LI_2016-03-04_emb5_pos2.lsm'
file_path = osp.join(data_dir, label_dir_rel, file_name,
                     'with_tracking', 'batch_1')

img_name = '00051.png'
img_path = osp.join(file_path, img_name)
img = PIL.Image.open(img_path)

# %%
plt.figure(figsize=(20, 20))
plt.imshow(img)
plt.plot(300, 560, 'ro', alpha=0.5, fillstyle='full', markersize=10)
plt.axis('off')
plt.show()
